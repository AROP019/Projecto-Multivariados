# %%
import pandas as pd
import numpy as np
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import re
import os
from pandas import ExcelWriter

# %% [markdown]
# #Lectura y filtrado inicial de datos

# %%
Norte2_2020 = pd.read_excel('Datos2020.xlsx', sheet_name='Norte2')
Sureste2_2020 = pd.read_excel('Datos2020.xlsx', sheet_name='Sureste2')
Suroeste_2020 = pd.read_excel('Datos2020.xlsx', sheet_name='Suroeste')
Noroeste2_2020 = pd.read_excel('Datos2020.xlsx', sheet_name='Noroeste2')
Centro_2020 = pd.read_excel('Datos2020.xlsx', sheet_name='Centro')

# %%
dataframes = [Norte2_2020, Sureste2_2020, Suroeste_2020, Noroeste2_2020, Centro_2020]

for df in dataframes:
        df.replace('NULL', np.nan, inplace=True)

# %%
Norte2_2020f = Norte2_2020[Norte2_2020["Fecha y hora"].dt.hour.isin([0, 6, 12, 18])]
Sureste2_2020f = Sureste2_2020[Sureste2_2020["Fecha y hora"].dt.hour.isin([0, 6, 12, 18])]
Suroeste_2020f = Suroeste_2020[Suroeste_2020["Fecha y hora"].dt.hour.isin([0, 6, 12, 18])]
Noroeste2_2020f = Noroeste2_2020[Noroeste2_2020["Fecha y hora"].dt.hour.isin([0, 6, 12, 18])]
Centro_2020f = Centro_2020[Centro_2020["Fecha y hora"].dt.hour.isin([0, 6, 12, 18])]

# %%
Norte2_2021 = pd.read_excel('Datos2021.xlsx', sheet_name='Norte2')
Sureste2_2021 = pd.read_excel('Datos2021.xlsx', sheet_name='Sureste2')
Suroeste_2021 = pd.read_excel('Datos2021.xlsx', sheet_name='Suroeste')
Noroeste2_2021 = pd.read_excel('Datos2021.xlsx', sheet_name='Noroeste2')
Centro_2021 = pd.read_excel('Datos2021.xlsx', sheet_name='Centro')

# %%
dataframes_2021 = [Norte2_2021, Sureste2_2021, Suroeste_2021, Noroeste2_2021, Centro_2021]
No = ['Fecha y hora']

for df in dataframes_2021:
    columnas_numericas = df.columns.drop(No, errors='ignore')
    df[columnas_numericas] = df[columnas_numericas].apply(
        pd.to_numeric, errors='coerce'
    ).astype('float64')

# %%
Norte2_2021f = Norte2_2021[Norte2_2021["Fecha y hora"].dt.hour.isin([0, 6, 12, 18])]
Sureste2_2021f = Sureste2_2021[Sureste2_2021["Fecha y hora"].dt.hour.isin([0, 6, 12, 18])]
Suroeste_2021f = Suroeste_2021[Suroeste_2021["Fecha y hora"].dt.hour.isin([0, 6, 12, 18])]
Noroeste2_2021f = Noroeste2_2021[Noroeste2_2021["Fecha y hora"].dt.hour.isin([0, 6, 12, 18])]
Centro_2021f = Centro_2021[Centro_2021["Fecha y hora"].dt.hour.isin([0, 6, 12, 18])]

# %%
Norte2_2022 = pd.read_excel('Datos2022.xlsx', sheet_name='Norte2')
Sureste2_2022 = pd.read_excel('Datos2022.xlsx', sheet_name='Sureste2')
Suroeste_2022 = pd.read_excel('Datos2022.xlsx', sheet_name='Suroeste')
Noroeste2_2022 = pd.read_excel('Datos2022.xlsx', sheet_name='Noroeste2')
Centro_2022 = pd.read_excel('Datos2022.xlsx', sheet_name='Centro')

# %%
dataframes = [Norte2_2022, Sureste2_2022, Suroeste_2022, Noroeste2_2022, Centro_2022]

for df in dataframes:
        df.replace('NULL', np.nan, inplace=True)

# %%
Norte2_2022f = Norte2_2022[Norte2_2022["Fecha y hora"].dt.hour.isin([0, 6, 12, 18])]
Sureste2_2022f = Sureste2_2022[Sureste2_2022["Fecha y hora"].dt.hour.isin([0, 6, 12, 18])]
Suroeste_2022f = Suroeste_2022[Suroeste_2022["Fecha y hora"].dt.hour.isin([0, 6, 12, 18])]
Noroeste2_2022f = Noroeste2_2022[Noroeste2_2022["Fecha y hora"].dt.hour.isin([0, 6, 12, 18])]
Centro_2022f = Centro_2022[Centro_2022["Fecha y hora"].dt.hour.isin([0, 6, 12, 18])]

# %%
Norte2_2023 = pd.read_excel('Datos2023.xlsx', sheet_name='Norte2')
Sureste2_2023 = pd.read_excel('Datos2023.xlsx', sheet_name='Sureste2')
Noroeste3_2023 = pd.read_excel('Datos2023.xlsx', sheet_name='Noroeste3')
Suroeste_2023 = pd.read_excel('Datos2023.xlsx', sheet_name='Suroeste')
Noroeste2_2023 = pd.read_excel('Datos2023.xlsx', sheet_name='Noroeste2')
Centro_2023 = pd.read_excel('Datos2023.xlsx', sheet_name='Centro')

# %%
Norte2_2023f = Norte2_2023[Norte2_2023["Fecha y hora"].dt.hour.isin([0, 6, 12, 18])]
Sureste2_2023f = Sureste2_2023[Sureste2_2023["Fecha y hora"].dt.hour.isin([0, 6, 12, 18])]
Noroeste3_2023f = Noroeste3_2023[Noroeste3_2023["Fecha y hora"].dt.hour.isin([0, 6, 12, 18])]
Suroeste_2023f = Suroeste_2023[Suroeste_2023["Fecha y hora"].dt.hour.isin([0, 6, 12, 18])]
Noroeste2_2023f = Noroeste2_2023[Noroeste2_2023["Fecha y hora"].dt.hour.isin([0, 6, 12, 18])]
Centro_2023f = Centro_2023[Centro_2023["Fecha y hora"].dt.hour.isin([0, 6, 12, 18])]

# %%
Norte2_2024 = pd.read_excel('Datos2024.xlsx', sheet_name='Norte2')
Sureste2_2024 = pd.read_excel('Datos2024.xlsx', sheet_name='Sureste2')
Noroeste3_2024 = pd.read_excel('Datos2024.xlsx', sheet_name='Noroeste3')
Suroeste_2024 = pd.read_excel('Datos2024.xlsx', sheet_name='Suroeste')
Noroeste2_2024 = pd.read_excel('Datos2024.xlsx', sheet_name='Noroeste2')
Centro_2024 = pd.read_excel('Datos2024.xlsx', sheet_name='Centro')

# %%
Norte2_2024f = Norte2_2024[Norte2_2024["Fecha y hora"].dt.hour.isin([0, 6, 12, 18])]
Sureste2_2024f = Sureste2_2024[Sureste2_2024["Fecha y hora"].dt.hour.isin([0, 6, 12, 18])]
Noroeste3_2024f = Noroeste3_2024[Noroeste3_2024["Fecha y hora"].dt.hour.isin([0, 6, 12, 18])]
Suroeste_2024f = Suroeste_2024[Suroeste_2024["Fecha y hora"].dt.hour.isin([0, 6, 12, 18])]
Noroeste2_2024f = Noroeste2_2024[Noroeste2_2024["Fecha y hora"].dt.hour.isin([0, 6, 12, 18])]
Centro_2024f = Centro_2024[Centro_2024["Fecha y hora"].dt.hour.isin([0, 6, 12, 18])]

# %%
Norte2_2025 = pd.read_excel('Datos2025.xlsx', sheet_name='Norte2')
Sureste2_2025 = pd.read_excel('Datos2025.xlsx', sheet_name='Sureste2')
Noroeste3_2025 = pd.read_excel('Datos2025.xlsx', sheet_name='Noroeste3')
Suroeste_2025 = pd.read_excel('Datos2025.xlsx', sheet_name='Suroeste')
Noroeste2_2025 = pd.read_excel('Datos2025.xlsx', sheet_name='Noroeste2')
Centro_2025 = pd.read_excel('Datos2025.xlsx', sheet_name='Centro')

# %%
Norte2_2025f = Norte2_2025[Norte2_2025["Fecha y hora"].dt.hour.isin([0, 6, 12, 18])]
Sureste2_2025f = Sureste2_2025[Sureste2_2025["Fecha y hora"].dt.hour.isin([0, 6, 12, 18])]
Noroeste3_2025f = Noroeste3_2025[Noroeste3_2025["Fecha y hora"].dt.hour.isin([0, 6, 12, 18])]
Suroeste_2025f = Suroeste_2025[Suroeste_2025["Fecha y hora"].dt.hour.isin([0, 6, 12, 18])]
Noroeste2_2025f = Noroeste2_2025[Noroeste2_2025["Fecha y hora"].dt.hour.isin([0, 6, 12, 18])]
Centro_2025f = Centro_2025[Centro_2025["Fecha y hora"].dt.hour.isin([0, 6, 12, 18])]

# %% [markdown]
# #Mantener las variables en el rango proporcionado

# %%
import pandas as pd

rangos = {
    2020: {"PM10": (0,900), "PM2.5": (0,800), "O3": (0,175), "NO": (0,500), "NO2": (0,175),
           "NOX": (0,500), "SO2": (0,250), "CO": (0,14), "RH": (0,100), "WSR": (0,40),
           "TOUT": (0,45), "SR": (0,1), "PRS": (690,740), "WDR": (0,360), "RAINF": (0,70)},
    2021: {"PM10": (0,900), "PM2.5": (0,800), "O3": (0,175), "NO": (0,500), "NO2": (0,175),
           "NOX": (0,500), "SO2": (0,250), "CO": (0,14), "RH": (0,100), "WSR": (0,40),
           "TOUT": (0,45), "SR": (0,1), "PRS": (690,740), "WDR": (0,360), "RAINF": (0,70)},
    2022: {"PM10": (0,900), "PM2.5": (0,800), "O3": (0,175), "NO": (0,500), "NO2": (0,175),
           "NOX": (0,500), "SO2": (0,250), "CO": (0,14), "RH": (0,100), "WSR": (0,40),
           "TOUT": (0,45), "SR": (0,1), "PRS": (690,740), "WDR": (0,360), "RAINF": (0,70)},
    2023: {"PM10": (0,900), "PM2.5": (0,800), "O3": (0,175), "NO": (0,500), "NO2": (0,175),
           "NOX": (0,500), "SO2": (0,250), "CO": (0,14), "RH": (0,100), "WSR": (0,40),
           "TOUT": (0,45), "SR": (0,1), "PRS": (690,740), "WDR": (0,360), "RAINF": (0,70)},

    2024: {"PM10": (0,999), "PM2.5": (0,999), "O3": (0,180), "NO": (0,400), "NO2": (0,130),
           "NOX": (0,500), "SO2": (0,150), "CO": (0,18), "RH": (0,100), "WSR": (0,38),
           "TOUT": (-4,45.5), "SR": (0,1.26), "PRS": (687.5,740), "WDR": (0,360), "RAINF": (0,50)},

    2025: {"PM10": (0,820), "PM2.5": (0,350), "O3": (0,185), "NO": (0,350), "NO2": (0,175),
           "NOX": (0,400), "SO2": (0,405), "CO": (0,10), "RH": (0,100), "WSR": (0,40),
           "TOUT": (-4.5,45), "SR": (0,1.2), "PRS": (688,740), "WDR": (0,360), "RAINF": (0,25)},
}


mapa_columnas = {
    "CO (ppm)": "CO", "NO (ppb)": "NO", "NO2 (ppb)": "NO2", "NOX (ppb)": "NOX",
    "O3 (ppb)": "O3", "PM10 (ug/m3)": "PM10", "PM2.5 (ug/m3)": "PM2.5",
    "PRS (mmHg)": "PRS", "RAINF (mm/h)": "RAINF", "RH (%)": "RH",
    "SO2 (ppb)": "SO2", "SR (kW/m2)": "SR", "TOUT (ºC)": "TOUT",
    "WSR (km/h)": "WSR", "WDR (azimutal)": "WDR"
}



def aplicar_rangos_suaves(df, año):

    r = rangos[año]
    df_filtrado = df.copy()

    for col_real, col_rango in mapa_columnas.items():
        if col_real in df.columns and col_rango in r:
            min_val, max_val = r[col_rango]

            fuera_rango = ~df[col_real].between(min_val, max_val, inclusive="both")

            df_filtrado.loc[fuera_rango, col_real] = np.nan

    return df_filtrado

dataframes = {
    # Año 2020
    "Norte2_2020f": Norte2_2020f,
    "Sureste2_2020f": Sureste2_2020f,
    "Suroeste_2020f": Suroeste_2020f,
    "Noroeste2_2020f": Noroeste2_2020f,
    "Centro_2020f": Centro_2020f,

    # Año 2021
    "Norte2_2021f": Norte2_2021f,
    "Sureste2_2021f": Sureste2_2021f,
    "Suroeste_2021f": Suroeste_2021f,
    "Noroeste2_2021f": Noroeste2_2021f,
    "Centro_2021f": Centro_2021f,

    # Año 2022
    "Norte2_2022f": Norte2_2022f,
    "Sureste2_2022f": Sureste2_2022f,
    "Suroeste_2022f": Suroeste_2022f,
    "Noroeste2_2022f": Noroeste2_2022f,
    "Centro_2022f": Centro_2022f,

    # Año 2023
    "Norte2_2023f": Norte2_2023f,
    "Sureste2_2023f": Sureste2_2023f,
    "Noroeste3_2023f": Noroeste3_2023f,
    "Suroeste_2023f": Suroeste_2023f,
    "Noroeste2_2023f": Noroeste2_2023f,
    "Centro_2023f": Centro_2023f,

    # Año 2024
    "Norte2_2024f": Norte2_2024f,
    "Sureste2_2024f": Sureste2_2024f,
    "Noroeste3_2024f": Noroeste3_2024f,
    "Suroeste_2024f": Suroeste_2024f,
    "Noroeste2_2024f": Noroeste2_2024f,
    "Centro_2024f": Centro_2024f,

    # Año 2025
    "Norte2_2025f": Norte2_2025f,
    "Sureste2_2025f": Sureste2_2025f,
    "Noroeste3_2025f": Noroeste3_2025f,
    "Suroeste_2025f": Suroeste_2025f,
    "Noroeste2_2025f": Noroeste2_2025f,
    "Centro_2025f": Centro_2025f,
}


filtrados = {}
for nombre, df in dataframes.items():
    match = re.search(r"\d{4}", nombre)
    año = int(match.group())
    df_filtrado = aplicar_rangos_suaves(df, año)
    filtrados[nombre] = df_filtrado
    print(f"{nombre}: {len(df)} filas procesadas. Valores fuera de rango reemplazados con NaN.")
# Out:
# Norte2_2020f: 1460 filas procesadas. Valores fuera de rango reemplazados con NaN.
# Sureste2_2020f: 1460 filas procesadas. Valores fuera de rango reemplazados con NaN.
# Suroeste_2020f: 1460 filas procesadas. Valores fuera de rango reemplazados con NaN.
# Noroeste2_2020f: 1460 filas procesadas. Valores fuera de rango reemplazados con NaN.
# Centro_2020f: 1460 filas procesadas. Valores fuera de rango reemplazados con NaN.
# Norte2_2021f: 1488 filas procesadas. Valores fuera de rango reemplazados con NaN.
# Sureste2_2021f: 1488 filas procesadas. Valores fuera de rango reemplazados con NaN.
# Suroeste_2021f: 1488 filas procesadas. Valores fuera de rango reemplazados con NaN.
# Noroeste2_2021f: 1488 filas procesadas. Valores fuera de rango reemplazados con NaN.
# Centro_2021f: 1488 filas procesadas. Valores fuera de rango reemplazados con NaN.
# Norte2_2022f: 2376 filas procesadas. Valores fuera de rango reemplazados con NaN.
# ...

# %% [markdown]
# #Análisis Null

# %%
Norte2_2020f.info()
Sureste2_2020f.info()
Suroeste_2020f.info()
Noroeste2_2020f.info()
Centro_2020f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1460 entries, 0 to 8770
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Fecha y hora    1460 non-null   datetime64[ns]
#  1   CO (ppm)        1102 non-null   float64
#  2   NO (ppb)        339 non-null    float64
#  3   NO2 (ppb)       263 non-null    float64
#  4   NOX (ppb)       263 non-null    float64
#  5   O3 (ppb)        101 non-null    float64
#  6   PM10 (ug/m3)    1328 non-null   float64
#  7   PM2.5 (ug/m3)   826 non-null    float64
#  8   PRS (mmHg)      1418 non-null   float64
#  9   RAINF (mm/h)    1419 non-null   float64
#  10  RH (%)          1418 non-null   float64
#  11  SO2 (ppb)       435 non-null    float64
#  12  SR (kW/m2)      1444 non-null   float64
#  13  TOUT (ºC)       1419 non-null   float64
#  14  WSR (km/h)      1418 non-null   float64
#  15  WDR (azimutal)  1416 non-null   float64
# dtypes: datetime64[ns](1), float64(15)
# ...

# %%
Norte2_2021f.info()
Sureste2_2021f.info()
Suroeste_2021f.info()
Noroeste2_2021f.info()
Centro_2021f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1488 entries, 0 to 8754
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Fecha y hora    1488 non-null   datetime64[ns]
#  1   CO (ppm)        1468 non-null   float64
#  2   NO (ppb)        1184 non-null   float64
#  3   NO2 (ppb)       1183 non-null   float64
#  4   NOX (ppb)       1183 non-null   float64
#  5   O3 (ppb)        1348 non-null   float64
#  6   PM10 (ug/m3)    1425 non-null   float64
#  7   PM2.5 (ug/m3)   1378 non-null   float64
#  8   PRS (mmHg)      1466 non-null   float64
#  9   RAINF (mm/h)    1471 non-null   float64
#  10  RH (%)          1467 non-null   float64
#  11  SO2 (ppb)       467 non-null    float64
#  12  SR (kW/m2)      1486 non-null   float64
#  13  TOUT (ºC)       1467 non-null   float64
#  14  WSR (km/h)      1471 non-null   float64
#  15  WDR (azimutal)  1469 non-null   float64
# dtypes: datetime64[ns](1), float64(15)
# ...

# %%
Norte2_2022f.info()
Sureste2_2022f.info()
Suroeste_2022f.info()
Noroeste2_2022f.info()
Centro_2022f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2376 entries, 0 to 14249
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Fecha y hora    2376 non-null   datetime64[ns]
#  1   CO (ppm)        2343 non-null   float64
#  2   NO (ppb)        2343 non-null   float64
#  3   NO2 (ppb)       2343 non-null   float64
#  4   NOX (ppb)       2343 non-null   float64
#  5   O3 (ppb)        2305 non-null   float64
#  6   PM10 (ug/m3)    2325 non-null   float64
#  7   PM2.5 (ug/m3)   2214 non-null   float64
#  8   PRS (mmHg)      2339 non-null   float64
#  9   RAINF (mm/h)    2343 non-null   float64
#  10  RH (%)          2334 non-null   float64
#  11  SO2 (ppb)       2287 non-null   float64
#  12  SR (kW/m2)      2369 non-null   float64
#  13  TOUT (ºC)       2343 non-null   float64
#  14  WSR (km/h)      2343 non-null   float64
#  15  WDR (azimutal)  2339 non-null   float64
# dtypes: datetime64[ns](1), float64(15)
# ...

# %%
Norte2_2023f.info()
Sureste2_2023f.info()
Noroeste3_2023f.info()
Suroeste_2023f.info()
Noroeste2_2023f.info()
Centro_2023f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1460 entries, 0 to 8752
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Fecha y hora    1460 non-null   datetime64[ns]
#  1   CO (ppm)        1387 non-null   float64
#  2   NO (ppb)        1395 non-null   float64
#  3   NO2 (ppb)       1395 non-null   float64
#  4   NOX (ppb)       1416 non-null   float64
#  5   O3 (ppb)        1433 non-null   float64
#  6   PM10 (ug/m3)    1176 non-null   float64
#  7   PM2.5 (ug/m3)   1408 non-null   float64
#  8   PRS (mmHg)      1452 non-null   float64
#  9   RAINF (mm/h)    1410 non-null   float64
#  10  RH (%)          1436 non-null   float64
#  11  SO2 (ppb)       1459 non-null   float64
#  12  SR (kW/m2)      1411 non-null   float64
#  13  TOUT (ºC)       1452 non-null   float64
#  14  WSR (km/h)      1451 non-null   float64
#  15  WDR (azimutal)  48 non-null     float64
# dtypes: datetime64[ns](1), float64(15)
# ...

# %%
Norte2_2024f.info()
Sureste2_2024f.info()
Noroeste3_2024f.info()
Suroeste_2024f.info()
Noroeste2_2024f.info()
Centro_2024f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1464 entries, 0 to 8776
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Fecha y hora    1464 non-null   datetime64[ns]
#  1   CO (ppm)        1427 non-null   float64
#  2   NO (ppb)        1436 non-null   float64
#  3   NO2 (ppb)       1437 non-null   float64
#  4   NOX (ppb)       1437 non-null   float64
#  5   O3 (ppb)        1368 non-null   float64
#  6   PM10 (ug/m3)    1430 non-null   float64
#  7   PM2.5 (ug/m3)   1322 non-null   float64
#  8   PRS (mmHg)      1435 non-null   float64
#  9   RAINF (mm/h)    1437 non-null   float64
#  10  RH (%)          1432 non-null   float64
#  11  SO2 (ppb)       1437 non-null   float64
#  12  SR (kW/m2)      1452 non-null   float64
#  13  TOUT (ºC)       1437 non-null   float64
#  14  WSR (km/h)      1436 non-null   float64
#  15  WDR (azimutal)  1436 non-null   float64
# dtypes: datetime64[ns](1), float64(15)
# ...

# %%
Norte2_2025f.info()
Sureste2_2025f.info()
Noroeste3_2025f.info()
Suroeste_2025f.info()
Noroeste2_2025f.info()
Centro_2025f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 724 entries, 1 to 4338
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Fecha y hora    724 non-null    datetime64[ns]
#  1   CO (ppm)        711 non-null    object
#  2   NO (ppb)        712 non-null    object
#  3   NO2 (ppb)       713 non-null    object
#  4   NOX (ppb)       713 non-null    object
#  5   O3 (ppb)        707 non-null    object
#  6   PM10 (ug/m3)    700 non-null    float64
#  7   PM2.5 (ug/m3)   657 non-null    float64
#  8   PRS (mmHg)      711 non-null    object
#  9   RAINF (mm/h)    712 non-null    object
#  10  RH (%)          709 non-null    object
#  11  SO2 (ppb)       713 non-null    object
#  12  SR (kW/m2)      721 non-null    object
#  13  TOUT (ºC)       712 non-null    object
#  14  WSR (km/h)      713 non-null    object
#  15  WDR (azimutal)  711 non-null    object
# dtypes: datetime64[ns](1), float64(2), object(13)
# ...

# %%
dataframes = {
    "Norte2_2020f": Norte2_2020f,
    "Sureste2_2020f": Sureste2_2020f,
    "Suroeste_2020f": Suroeste_2020f,
    "Noroeste2_2020f": Noroeste2_2020f,
    "Centro_2020f": Centro_2020f,

    "Norte2_2021f": Norte2_2021f,
    "Sureste2_2021f": Sureste2_2021f,
    "Suroeste_2021f": Suroeste_2021f,
    "Noroeste2_2021f": Noroeste2_2021f,
    "Centro_2021f": Centro_2021f,

    "Norte2_2022f": Norte2_2022f,
    "Sureste2_2022f": Sureste2_2022f,
    "Suroeste_2022f": Suroeste_2022f,
    "Noroeste2_2022f": Noroeste2_2022f,
    "Centro_2022f": Centro_2022f,

    "Norte2_2023f": Norte2_2023f,
    "Sureste2_2023f": Sureste2_2023f,
    "Noroeste3_2023f": Noroeste3_2023f,
    "Suroeste_2023f": Suroeste_2023f,
    "Noroeste2_2023f": Noroeste2_2023f,
    "Centro_2023f": Centro_2023f,

    "Norte2_2024f": Norte2_2024f,
    "Sureste2_2024f": Sureste2_2024f,
    "Noroeste3_2024f": Noroeste3_2024f,
    "Suroeste_2024f": Suroeste_2024f,
    "Noroeste2_2024f": Noroeste2_2024f,
    "Centro_2024f": Centro_2024f,

    "Norte2_2025f": Norte2_2025f,
    "Sureste2_2025f": Sureste2_2025f,
    "Noroeste3_2025f": Noroeste3_2025f,
    "Suroeste_2025f": Suroeste_2025f,
    "Noroeste2_2025f": Noroeste2_2025f,
    "Centro_2025f": Centro_2025f
}


for nombre, df in dataframes.items():
    print(f" DataFrame: {nombre}")

    total_filas = len(df)

    nulos_conteo = df.isnull().sum()

    nulos_porcentaje = (nulos_conteo / total_filas) * 100

    resumen_nulos = pd.DataFrame({
        'Valores Nulos (Conteo)': nulos_conteo,
        'Porcentaje Nulos (%)': nulos_porcentaje.round(2)
    })

    resumen_nulos = resumen_nulos[resumen_nulos['Valores Nulos (Conteo)'] > 0]

    if not resumen_nulos.empty:
        print(resumen_nulos)
    else:
        print("No se encontraron valores nulos en este DataFrame")

    print("\n" + "-"*40 + "\n")
# Out:
#  DataFrame: Norte2_2020f
#                 Valores Nulos (Conteo)  Porcentaje Nulos (%)
# CO (ppm)                           358                 24.52
# NO (ppb)                          1121                 76.78
# NO2 (ppb)                         1197                 81.99
# NOX (ppb)                         1197                 81.99
# O3 (ppb)                          1359                 93.08
# PM10 (ug/m3)                       132                  9.04
# PM2.5 (ug/m3)                      634                 43.42
# PRS (mmHg)                          42                  2.88
# RAINF (mm/h)                        41                  2.81
# RH (%)                              42                  2.88
# SO2 (ppb)                         1025                 70.21
# SR (kW/m2)                          16                  1.10
# TOUT (ºC)                           41                  2.81
# WSR (km/h)                          42                  2.88
# ...

# %% [markdown]
# #Imputación

# %%
dataframes = {
    "Norte2_2020f": Norte2_2020f,
    "Sureste2_2020f": Sureste2_2020f,
    "Suroeste_2020f": Suroeste_2020f,
    "Noroeste2_2020f": Noroeste2_2020f,
    "Centro_2020f": Centro_2020f,

    "Norte2_2021f": Norte2_2021f,
    "Sureste2_2021f": Sureste2_2021f,
    "Suroeste_2021f": Suroeste_2021f,
    "Noroeste2_2021f": Noroeste2_2021f,
    "Centro_2021f": Centro_2021f,

    "Norte2_2022f": Norte2_2022f,
    "Sureste2_2022f": Sureste2_2022f,
    "Suroeste_2022f": Suroeste_2022f,
    "Noroeste2_2022f": Noroeste2_2022f,
    "Centro_2022f": Centro_2022f,

    "Norte2_2023f": Norte2_2023f,
    "Sureste2_2023f": Sureste2_2023f,
    "Noroeste3_2023f": Noroeste3_2023f,
    "Suroeste_2023f": Suroeste_2023f,
    "Noroeste2_2023f": Noroeste2_2023f,
    "Centro_2023f": Centro_2023f,

    "Norte2_2024": Norte2_2024f,
    "Sureste2_2024f": Sureste2_2024f,
    "Noroeste3_2024f": Noroeste3_2024f,
    "Suroeste_2024f": Suroeste_2024f,
    "Noroeste2_2024f": Noroeste2_2024f,
    "Centro_2024f": Centro_2024f,

    "Norte2_2025f": Norte2_2025f,
    "Sureste2_2025f": Sureste2_2025f,
    "Noroeste3_2025f": Noroeste3_2025f,
    "Suroeste_2025f": Suroeste_2025f,
    "Noroeste2_2025f": Noroeste2_2025f,
    "Centro_2025f": Centro_2025f
}

# %%
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np

def imputar_knn(df, k=5):
    df = df.copy()

    date_col = df.columns[0]
    fechas = df[date_col].copy()
    datos = df.drop(columns=[date_col]).copy()

    cols_num = datos.select_dtypes(include=[np.number]).columns
    cols_imputar = [c for c in cols_num if datos[c].isna().mean() < 0.10]

    if not cols_imputar:
        return df, {}

    valores_antes = datos[cols_imputar].copy()
    datos_a_escalar = datos[cols_imputar].copy()

    # 1. ESTANDARIZACIÓN
    scaler = StandardScaler()
    datos_escalados = scaler.fit_transform(datos_a_escalar)
    datos_a_imputar_df = pd.DataFrame(datos_escalados, columns=cols_imputar, index=datos_a_escalar.index)

    # 2. IMPUTACIÓN KNN
    imputer = KNNImputer(n_neighbors=k)
    datos_imputados_escalados = imputer.fit_transform(datos_a_imputar_df)

    # 3. DESHACER ESCALAMIENTO (INVERSA)
    datos_imputados_df = pd.DataFrame(datos_imputados_escalados, columns=cols_imputar, index=datos_a_imputar_df.index)
    datos_finales_desescalados = scaler.inverse_transform(datos_imputados_df)

    # 4. ACTUALIZAR DATAFRAME ORIGINAL
    datos_knn = datos.copy()
    datos_knn[cols_imputar] = datos_finales_desescalados

    # 5. CONSTRUIR RESULTADO FINAL Y COMPARACIÓN
    df_final = pd.concat([fechas.reset_index(drop=True), datos_knn.reset_index(drop=True)], axis=1)

    comparacion = {}
    for col in cols_imputar:
        mask_na = valores_antes[col].isna()
        comparacion[col] = pd.DataFrame({
            "Antes (NA)": valores_antes[col][mask_na],
            "Después": datos_knn[col][mask_na]
        })

    return df_final, comparacion

# %%
dataframes_definitivos = {}
comparaciones_knn = {}

for nombre, df in dataframes.items():
    print(f"\nProcesando {nombre} con KNN...")

    df_imputado, comparacion = imputar_knn(df)

    nuevo_nombre = f"{nombre}Definitivo"
    dataframes_definitivos[nuevo_nombre] = df_imputado
    comparaciones_knn[nombre] = comparacion

print("\nImputación finalizada. Dataframes guardados en dataframes_definitivos.")
# Out:
# Procesando Norte2_2020f con KNN...
#
# Procesando Sureste2_2020f con KNN...
#
# Procesando Suroeste_2020f con KNN...
#
# Procesando Noroeste2_2020f con KNN...
#
# Procesando Centro_2020f con KNN...
#
# Procesando Norte2_2021f con KNN...
#
# Procesando Sureste2_2021f con KNN...
#
# Procesando Suroeste_2021f con KNN...
#
# Procesando Noroeste2_2021f con KNN...
#
# Procesando Centro_2021f con KNN...
#
# Procesando Norte2_2022f con KNN...
#
# Procesando Sureste2_2022f con KNN...
#
# Procesando Suroeste_2022f con KNN...
#
# Procesando Noroeste2_2022f con KNN...
#
# Procesando Centro_2022f con KNN...
#
# Procesando Norte2_2023f con KNN...
#
# Procesando Sureste2_2023f con KNN...
#
# Procesando Noroeste3_2023f con KNN...
#
# Procesando Suroeste_2023f con KNN...
#
# Procesando Noroeste2_2023f con KNN...
#
# Procesando Centro_2023f con KNN...
#
# Procesando Norte2_2024 con KNN...
#
# Procesando Sureste2_2024f con KNN...
#
# Procesando Noroeste3_2024f con KNN...
#
# ...

# %%
def extraer_anio(nombre):
    match = re.search(r"(20\d{2})", nombre)
    return match.group(1) if match else None


dataframes_por_anio = {}

for nombre, df in dataframes_definitivos.items():
    anio = extraer_anio(nombre)
    if anio is None:
        print(f"No se encontró año en: {nombre}")
        continue

    if anio not in dataframes_por_anio:
        dataframes_por_anio[anio] = {}

    dataframes_por_anio[anio][nombre] = df


carpeta = "ExcelsPorAnio"
os.makedirs(carpeta, exist_ok=True)

for anio, dfs in dataframes_por_anio.items():
    filepath = f"{carpeta}/{anio}.xlsx"

    with ExcelWriter(filepath, engine="openpyxl") as writer:
        for nombre_df, df in dfs.items():
            sheet_name = nombre_df[:31]
            df.to_excel(writer, sheet_name=sheet_name, index=False)

    print(f"Guardado: {filepath}")
# Out:
# Guardado: ExcelsPorAnio/2020.xlsx
# Guardado: ExcelsPorAnio/2021.xlsx
# Guardado: ExcelsPorAnio/2022.xlsx
# Guardado: ExcelsPorAnio/2023.xlsx
# Guardado: ExcelsPorAnio/2024.xlsx
# Guardado: ExcelsPorAnio/2025.xlsx

# %%
for nombre, comp in comparaciones_knn.items():
    print(f"\n--- {nombre} ---")
    for col, df_comp in comp.items():
        print(f"{col}: imputados = {df_comp.shape[0]} valores")
# Out:
# --- Norte2_2020f ---
# PM10 (ug/m3): imputados = 132 valores
# PRS (mmHg): imputados = 42 valores
# RAINF (mm/h): imputados = 41 valores
# RH (%): imputados = 42 valores
# SR (kW/m2): imputados = 16 valores
# TOUT (ºC): imputados = 41 valores
# WSR (km/h): imputados = 42 valores
# WDR (azimutal): imputados = 44 valores
#
# --- Sureste2_2020f ---
# SR (kW/m2): imputados = 7 valores
# WDR (azimutal): imputados = 126 valores
#
# --- Suroeste_2020f ---
# PM10 (ug/m3): imputados = 53 valores
# PM2.5 (ug/m3): imputados = 97 valores
# PRS (mmHg): imputados = 142 valores
# RAINF (mm/h): imputados = 20 valores
# RH (%): imputados = 28 valores
# SR (kW/m2): imputados = 14 valores
# TOUT (ºC): imputados = 21 valores
# WSR (km/h): imputados = 22 valores
#
# --- Noroeste2_2020f ---
# CO (ppm): imputados = 30 valores
# PM10 (ug/m3): imputados = 55 valores
# PRS (mmHg): imputados = 32 valores
# RAINF (mm/h): imputados = 31 valores
# RH (%): imputados = 37 valores
# ...
